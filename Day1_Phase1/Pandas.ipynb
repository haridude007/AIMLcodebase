# %%
import pandas as pd
import numpy as np

# %%
ser = pd.Series(dtype="object")
print(ser)
data = np.array(['g', 'e', 'e', 'k', 's'])
ser = pd.Series(data)
print(ser)
# Out:
# Series([], dtype: object)
# 0    g
# 1    e
# 2    e
# 3    k
# 4    s
# dtype: str

# %%
df = pd.DataFrame()
print(df) #prints empty dataframe and colums and index
lst = ['Geeks', 'For', 'Geeks', 'is', 'portal', 'for', 'Geeks']
df = pd.DataFrame(lst, columns=['Words'])
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
#     Words
# 0   Geeks
# 1     For
# 2   Geeks
# 3      is
# 4  portal
# 5     for
# 6   Geeks

# %%
# --- 1. Create a DataFrame ---
data = {
    'City': ['NYC', 'London', 'Paris', 'Tokyo', 'Sydney'],
    'Population_M': [8.4, 8.9, 2.1, 13.9, 5.3],
    'Country': ['USA', 'UK', 'France', 'Japan', 'Australia'],
    'GDP_B': [1800, 700, 750, 1900, 350]
}
df = pd.DataFrame(data)
print("Original DataFrame:")
print(df)
# Out:
# Original DataFrame:
#      City  Population_M    Country  GDP_B
# 0     NYC           8.4        USA   1800
# 1  London           8.9         UK    700
# 2   Paris           2.1     France    750
# 3   Tokyo          13.9      Japan   1900
# 4  Sydney           5.3  Australia    350

# %%
# --- 2. Data Selection and Filtering ---
# Select specific columns
cities_pop = df[['City', 'Population_M']]
print("\nSelected Columns:")
print(cities_pop)
# Out:
# Selected Columns:
#      City  Population_M
# 0     NYC           8.4
# 1  London           8.9
# 2   Paris           2.1
# 3   Tokyo          13.9
# 4  Sydney           5.3

# %%
# Filter rows where population is greater than 8 million
large_cities = df[df['Population_M'] > 8]
print("\nLarge Cities (Population > 8M):")
print(large_cities)
# Out:
# Large Cities (Population > 8M):
#      City  Population_M Country  GDP_B
# 0     NYC           8.4     USA   1800
# 1  London           8.9      UK    700
# 3   Tokyo          13.9   Japan   1900

# %%
# --- 3. Creating a New Column (Feature Engineering) ---
# Create a new column representing GDP per capita (approx)
df['GDP_per_Capita'] = (df['GDP_B'] / df['Population_M']).round(2)
print("\nDataFrame with New Column:")
print(df)
# Out:
# DataFrame with New Column:
#      City  Population_M    Country  GDP_B  GDP_per_Capita
# 0     NYC           8.4        USA   1800          214.29
# 1  London           8.9         UK    700           78.65
# 2   Paris           2.1     France    750          357.14
# 3   Tokyo          13.9      Japan   1900          136.69
# 4  Sydney           5.3  Australia    350           66.04

# %%
# --- 4. Grouping and Aggregation ---
# Group by a categorical column (Country in a real dataset) and calculate the mean
# Using 'Country' as a proxy for demonstration purposes here
country_stats = df.groupby('Country')['Population_M'].mean()
print("\nMean Population by Country:")
print(country_stats)
# Out:
# Mean Population by Country:
# Country
# Australia     5.3
# France        2.1
# Japan        13.9
# UK            8.9
# USA           8.4
# Name: Population_M, dtype: float64

# %%
df = pd.read_csv("customers.csv")

df.head()
df1 = pd.DataFrame(df)
print(df1)
# Out:
#      ID  FIRST_NAME LAST_NAME
# 0     1     Michael        P.
# 1     2       Shawn        M.
# 2     3    Kathleen        P.
# 3     4       Jimmy        C.
# 4     5   Katherine        R.
# ..  ...         ...       ...
# 95   96  Jacqueline        A.
# 96   97     Shirley        D.
# 97   98      Nicole        M.
# 98   99        Mary        G.
# 99  100        Jean        M.
#
# [100 rows x 3 columns]

# %%
data1 = {'Name': ['Jai', 'Anuj', 'Jai', 'Princi',
                  'Gaurav', 'Anuj', 'Princi', 'Abhi'],
         'Age': [27, 24, 22, 32,
                 33, 36, 27, 32],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj',
                     'Jaunpur', 'Kanpur', 'Allahabad', 'Aligarh'],
         'Qualification': ['Msc', 'MA', 'MCA', 'Phd',
                           'B.Tech', 'B.com', 'Msc', 'MA']}

df = pd.DataFrame(data1)

print("Original Dataframe")
print(df)

gk = df.groupby('Name')

print("After Creating Groups")
gk.first()
# Out:
# Original Dataframe
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1    Anuj   24     Kanpur            MA
# 2     Jai   22  Allahabad           MCA
# 3  Princi   32    Kannuaj           Phd
# 4  Gaurav   33    Jaunpur        B.Tech
# 5    Anuj   36     Kanpur         B.com
# 6  Princi   27  Allahabad           Msc
# 7    Abhi   32    Aligarh            MA
# After Creating Groups
#         Age  Address Qualification
# Name
# Abhi     32  Aligarh            MA
# Anuj     24   Kanpur            MA
# Gaurav   33  Jaunpur        B.Tech
# Jai      27   Nagpur           Msc
# Princi   32  Kannuaj           Phd
